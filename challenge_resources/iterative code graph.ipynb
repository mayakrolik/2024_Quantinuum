# %%
#iterative code in H1-1LE:
{
  "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
  "description": "Performance over iterations",
  "data": {
    "values": [
      {"Iteration": "1st", "Tuple": "(1, 1, 0)", "Performance": 97.6},
      {"Iteration": "1st", "Tuple": "(1, 0, 0)", "Performance": 0.8},
      {"Iteration": "1st", "Tuple": "(1, 1, 1)", "Performance": 0.7},
      {"Iteration": "1st", "Tuple": "(0, 0, 1)", "Performance": 0.3},
      {"Iteration": "1st", "Tuple": "(0, 1, 0)", "Performance": 0.2},
      {"Iteration": "1st", "Tuple": "(0, 0, 0)", "Performance": 0.2},
      {"Iteration": "1st", "Tuple": "(0, 1, 1)", "Performance": 0.2},
      {"Iteration": "1st", "Tuple": "(1, 0, 1)", "Performance": 0.0},
      {"Iteration": "2nd", "Tuple": "(1, 1, 0)", "Performance": 97.1},
      {"Iteration": "2nd", "Tuple": "(1, 1, 1)", "Performance": 0.9},
      {"Iteration": "2nd", "Tuple": "(0, 1, 0)", "Performance": 0.6},
      {"Iteration": "2nd", "Tuple": "(1, 0, 0)", "Performance": 0.6},
      {"Iteration": "2nd", "Tuple": "(1, 0, 1)", "Performance": 0.2},
      {"Iteration": "2nd", "Tuple": "(0, 0, 0)", "Performance": 0.2},
      {"Iteration": "2nd", "Tuple": "(0, 0, 1)", "Performance": 0.2},
      {"Iteration": "2nd", "Tuple": "(0, 1, 1)", "Performance": 0.2},
      {"Iteration": "3rd", "Tuple": "(1, 1, 0)", "Performance": 97.5},
      {"Iteration": "3rd", "Tuple": "(1, 1, 1)", "Performance": 1.0},
      {"Iteration": "3rd", "Tuple": "(0, 1, 0)", "Performance": 0.5},
      {"Iteration": "3rd", "Tuple": "(1, 0, 0)", "Performance": 0.3},
      {"Iteration": "3rd", "Tuple": "(1, 0, 1)", "Performance": 0.3},
      {"Iteration": "3rd", "Tuple": "(0, 0, 0)", "Performance": 0.2},
      {"Iteration": "3rd", "Tuple": "(0, 0, 1)", "Performance": 0.2},
      {"Iteration": "3rd", "Tuple": "(0, 1, 1)", "Performance": 0.0}
    ]
  },
  "mark": "line",
  "encoding": {
    "x": {
      "field": "Tuple", 
      "type": "nominal",
      "axis": {
        "title": "Tuple"
      }
    },
    "y": {
      "field": "Performance", 
      "type": "quantitative",
      "axis": {
        "title": "Performance (%)",
        "labelExpr": "datum.value + '%'"
      }
    },
    "color": {
      "field": "Iteration",
      "type": "nominal"
    }
  },
  "width": 400,
  "height": 300
}
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v5.json',
#  'description': 'Performance over iterations',
#  'data': {'values': [{'Iteration': '1st',
#     'Tuple': '(1, 1, 0)',
#     'Performance': 97.6},
#    {'Iteration': '1st', 'Tuple': '(1, 0, 0)', 'Performance': 0.8},
#    {'Iteration': '1st', 'Tuple': '(1, 1, 1)', 'Performance': 0.7},
#    {'Iteration': '1st', 'Tuple': '(0, 0, 1)', 'Performance': 0.3},
#    {'Iteration': '1st', 'Tuple': '(0, 1, 0)', 'Performance': 0.2},
#    {'Iteration': '1st', 'Tuple': '(0, 0, 0)', 'Performance': 0.2},
#    {'Iteration': '1st', 'Tuple': '(0, 1, 1)', 'Performance': 0.2},
#    {'Iteration': '1st', 'Tuple': '(1, 0, 1)', 'Performance': 0.0},
#    {'Iteration': '2nd', 'Tuple': '(1, 1, 0)', 'Performance': 97.1},
#    {'Iteration': '2nd', 'Tuple': '(1, 1, 1)', 'Performance': 0.9},
#    {'Iteration': '2nd', 'Tuple': '(0, 1, 0)', 'Performance': 0.6},
#    {'Iteration': '2nd', 'Tuple': '(1, 0, 0)', 'Performance': 0.6},
# ...

# %%
#iterative code in H1-1E:
{
  "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
  "description": "Performance over iterations",
  "data": {
    "values": [
      {"Iteration": "1st", "Tuple": "(1, 1, 0)", "Performance": 94.8},
      {"Iteration": "1st", "Tuple": "(1, 0, 0)", "Performance": 1.1},
      {"Iteration": "1st", "Tuple": "(1, 1, 1)", "Performance": 1.1},
      {"Iteration": "1st", "Tuple": "(0, 0, 1)", "Performance": 1.0},
      {"Iteration": "1st", "Tuple": "(0, 1, 0)", "Performance": 0.9},
      {"Iteration": "1st", "Tuple": "(0, 0, 0)", "Performance": 0.7},
      {"Iteration": "1st", "Tuple": "(0, 1, 1)", "Performance": 0.2},
      {"Iteration": "1st", "Tuple": "(1, 0, 1)", "Performance": 0.2},
      {"Iteration": "2nd", "Tuple": "(1, 1, 0)", "Performance": 94.6},
      {"Iteration": "2nd", "Tuple": "(1, 1, 1)", "Performance": 1.5},
      {"Iteration": "2nd", "Tuple": "(0, 1, 0)", "Performance": 1.3},
      {"Iteration": "2nd", "Tuple": "(1, 0, 0)", "Performance": 1.0},
      {"Iteration": "2nd", "Tuple": "(1, 0, 1)", "Performance": 0.8},
      {"Iteration": "2nd", "Tuple": "(0, 0, 0)", "Performance": 0.5},
      {"Iteration": "2nd", "Tuple": "(0, 0, 1)", "Performance": 0.2},
      {"Iteration": "2nd", "Tuple": "(0, 1, 1)", "Performance": 0.1},
      {"Iteration": "3rd", "Tuple": "(1, 1, 0)", "Performance": 94.6},
      {"Iteration": "3rd", "Tuple": "(1, 1, 1)", "Performance": 1.5},
      {"Iteration": "3rd", "Tuple": "(0, 1, 0)", "Performance": 1.3},
      {"Iteration": "3rd", "Tuple": "(1, 0, 0)", "Performance": 1.0},
      {"Iteration": "3rd", "Tuple": "(1, 0, 1)", "Performance": 0.8},
      {"Iteration": "3rd", "Tuple": "(0, 0, 0)", "Performance": 0.5},
      {"Iteration": "3rd", "Tuple": "(0, 0, 1)", "Performance": 0.2},
      {"Iteration": "3rd", "Tuple": "(0, 1, 1)", "Performance": 0.1}
    ]
  },
  "mark": "line",
  "encoding": {
    "x": {
      "field": "Tuple", 
      "type": "nominal",
      "axis": {
        "title": "Tuple"
      }
    },
    "y": {
      "field": "Performance", 
      "type": "quantitative",
      "axis": {
        "title": "Performance (%)",
        "labelExpr": "datum.value + '%'"
      }
    },
    "color": {
      "field": "Iteration",
      "type": "nominal"
    }
  },
  "width": 400,
  "height": 300
}
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v5.json',
#  'description': 'Performance over iterations',
#  'data': {'values': [{'Iteration': '1st',
#     'Tuple': '(1, 1, 0)',
#     'Performance': 94.8},
#    {'Iteration': '1st', 'Tuple': '(1, 0, 0)', 'Performance': 1.1},
#    {'Iteration': '1st', 'Tuple': '(1, 1, 1)', 'Performance': 1.1},
#    {'Iteration': '1st', 'Tuple': '(0, 0, 1)', 'Performance': 1.0},
#    {'Iteration': '1st', 'Tuple': '(0, 1, 0)', 'Performance': 0.9},
#    {'Iteration': '1st', 'Tuple': '(0, 0, 0)', 'Performance': 0.7},
#    {'Iteration': '1st', 'Tuple': '(0, 1, 1)', 'Performance': 0.2},
#    {'Iteration': '1st', 'Tuple': '(1, 0, 1)', 'Performance': 0.2},
#    {'Iteration': '2nd', 'Tuple': '(1, 1, 0)', 'Performance': 94.6},
#    {'Iteration': '2nd', 'Tuple': '(1, 1, 1)', 'Performance': 1.5},
#    {'Iteration': '2nd', 'Tuple': '(0, 1, 0)', 'Performance': 1.3},
#    {'Iteration': '2nd', 'Tuple': '(1, 0, 0)', 'Performance': 1.0},
# ...
